# %%
import athlete
import gymnasium as gym
import torch

# %%
env = gym.make("CartPole-v1", render_mode="human")
# Initialize the agent, all hyperparameters have default values
# which can be overridden with keyword arguments
agent = athlete.make(
    algorithm_id="dqn",
    action_space=env.action_space,
    observation_space=env.observation_space,
    #seed=42 # optional
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 4
#       1 env = gym.make("CartPole-v1", render_mode="human")
#       2 # Initialize the agent, all hyperparameters have default values
#       3 # which can be overridden with keyword arguments
# ----> 4 agent = athlete.make(
#       5     algorithm_id="dqn",
#       6     action_space=env.action_space,
#       7     observation_space=env.observation_space,
#
# File D:\ActorDQN\Athlete\athlete\agent.py:404, in Agent.make(cls, observation_space, action_space, algorithm_id, seed, **kwargs)
#     398         warn(
#     399             f"Key {key} is not part of the default configuration of the algorithm {algorithm_id}. "
#     400             "It's likely that this setting is not used by the algorithm and will be ignored.",
#     401         )
#     403 # RNG Handler
# --> 404 rng_handler = RNGHandler(seed)
#     405 RNGHandler.set_global_instance(rng_handler=rng_handler)
#     407 step_tracker = StepTracker(
#     408     warmup_steps=updated_configuration.get(
#     409         constants.GENERAL_ARGUMENT_WARMUP_STEPS, 0
#     410     ),
#     411 )
#
# File D:\ActorDQN\Athlete\athlete\global_objects.py:253, in RNGHandler.__init__(self, seed)
#     246 """Initializes a RNGHandler instance. This can be different from the global instance.
#     247
#     248 Args:
#     249     seed (Optional[int], optional): Seed for the random number generator. If None, a random seed will be generated. Defaults to None.
#     250 """
#     252 if not seed:
# --> 253     seed = int(np.random.randint(low=0, high=np.iinfo(np.uint32).max))
#     254 self.seed = seed
#     256 # For convenience this ensures reproducibility for functions that do not use the global rng but numpy or torch
#     257 # as long as they are used in the same order
#     258 # Set seed for all numpy functions
#
# File numpy/random/mtrand.pyx:799, in numpy.random.mtrand.RandomState.randint()
# --> 799 'Could not get source, probably due dynamically evaluated source code.'
#
# File numpy/random/_bounded_integers.pyx:2881, in numpy.random._bounded_integers._rand_int32()
# -> 2881 'Could not get source, probably due dynamically evaluated source code.'
#
# ValueError: high is out of bounds for int32
